# %% [markdown]
# # Generating Frequent Itemsets

# %% [markdown]
# The apriori function expects data in a one-hot encoded pandas DataFrame. Suppose we have the following transaction data:

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %% [markdown]
# We can transform it into the right format via the TransactionEncoder as follows:

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
df.shape
# Out:
# (5, 11)

# %% [markdown]
# Now, let us return the items and itemsets with at least 60% support:

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemset = apriori(df, min_support=0.6)
frequent_itemset
# Out:
#     support   itemsets
# 0       0.8        (3)
# 1       1.0        (5)
# 2       0.6        (6)
# 3       0.6        (8)
# 4       0.6       (10)
# 5       0.8     (3, 5)
# 6       0.6     (8, 3)
# 7       0.6     (5, 6)
# 8       0.6     (8, 5)
# 9       0.6    (10, 5)
# 10      0.6  (8, 3, 5)

# %% [markdown]
# By default, apriori returns the column indices of the items, which may be useful in downstream operations such as association rule mining. For better readability, we can set use_colnames=True to convert these integer values into the respective item names:

# %%
frequent_itemset = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemset
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Kidney Beans, Onion, Eggs)

# %% [markdown]
# # Selecting and Filtering Results

# %% [markdown]
# The advantage of working with pandas DataFrames is that we can use its convenient features to filter the results. For instance, let's assume we are only interested in itemsets of length 2 that have a support of at least 80 percent. First, we create the frequent itemsets via apriori and add a new column that stores the length of each itemset:

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                     itemsets  length
# 0       0.8                       (Eggs)       1
# 1       1.0               (Kidney Beans)       1
# 2       0.6                       (Milk)       1
# 3       0.6                      (Onion)       1
# 4       0.6                     (Yogurt)       1
# 5       0.8         (Kidney Beans, Eggs)       2
# 6       0.6                (Onion, Eggs)       2
# 7       0.6         (Kidney Beans, Milk)       2
# 8       0.6        (Kidney Beans, Onion)       2
# 9       0.6       (Kidney Beans, Yogurt)       2
# 10      0.6  (Kidney Beans, Onion, Eggs)       3

# %% [markdown]
# Then, we can select the results that satisfy our desired criteria as follows:

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.8) ]
# Out:
#    support              itemsets  length
# 5      0.8  (Kidney Beans, Eggs)       2

# %% [markdown]
# Similarly, using the Pandas API, we can select entries based on the "itemsets" column:

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'Onion', 'Eggs'} ]
# Out:
#    support       itemsets  length
# 6      0.6  (Onion, Eggs)       2

# %% [markdown]
# ##### Frozensets
#
# Note that the entries in the "itemsets" column are of type frozenset, which is built-in Python type that is similar to a Python set but immutable, which makes it more efficient for certain query or comparison operations (https://docs.python.org/3.6/library/stdtypes.html#frozenset). Since frozensets are sets, the item order does not matter. I.e., the query

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'Eggs', 'Onion'} ]
# Out:
#    support       itemsets  length
# 6      0.6  (Onion, Eggs)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == frozenset(('Eggs', 'Onion')) ]
# Out:
#    support       itemsets  length
# 6      0.6  (Onion, Eggs)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == frozenset(('Onion', 'Eggs')) ]
# Out:
#    support       itemsets  length
# 6      0.6  (Onion, Eggs)       2

# %% [markdown]
# # Working with Sparse Representations

# %% [markdown]
# To save memory, you may want to represent your transaction data in the sparse format. This is especially useful if you have lots of products and small transactions.

# %%
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
sparse_df = pd.SparseDataFrame(te_ary, columns=te.columns_, default_fill_value=False)
sparse_df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
apriori(sparse_df, min_support=0.6, use_colnames=True)
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Kidney Beans, Eggs)
# 6       0.6                (Onion, Eggs)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Kidney Beans, Onion, Eggs)

# %%
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(df, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#       antecedents     consequents  antecedent support  consequent support  \
# 0          (Eggs)         (Apple)                 0.8                 0.2
# 1         (Apple)          (Eggs)                 0.2                 0.8
# 2  (Kidney Beans)         (Apple)                 1.0                 0.2
# 3         (Apple)  (Kidney Beans)                 0.2                 1.0
# 4          (Milk)         (Apple)                 0.6                 0.2
#
#    support  confidence      lift  leverage  conviction
# 0      0.2    0.250000  1.250000      0.04    1.066667
# 1      0.2    1.000000  1.250000      0.04         inf
# 2      0.2    0.200000  1.000000      0.00    1.000000
# 3      0.2    1.000000  1.000000      0.00         inf
# 4      0.2    0.333333  1.666667      0.08    1.200000

# %%
rules[ (rules['lift'] >= 5) &
      (rules['confidence'] >= 0.6) ]
# Out:
#                             antecedents                         consequents  \
# 75                         (Corn, Eggs)                         (Ice cream)
# 78                          (Ice cream)                        (Corn, Eggs)
# 92                        (Corn, Onion)                         (Ice cream)
# 97                          (Ice cream)                       (Corn, Onion)
# 110                        (Milk, Corn)                           (Unicorn)
# 115                           (Unicorn)                        (Milk, Corn)
# 123                      (Corn, Yogurt)                           (Unicorn)
# 126                           (Unicorn)                      (Corn, Yogurt)
# 323          (Kidney Beans, Corn, Eggs)                         (Ice cream)
# 327           (Kidney Beans, Ice cream)                        (Corn, Eggs)
# 330                        (Corn, Eggs)           (Kidney Beans, Ice cream)
# 334                         (Ice cream)          (Kidney Beans, Corn, Eggs)
# 336                 (Corn, Onion, Eggs)                         (Ice cream)
# 340                       (Corn, Onion)                   (Ice cream, Eggs)
# 341                        (Corn, Eggs)                  (Ice cream, Onion)
# 344                  (Ice cream, Onion)                        (Corn, Eggs)
# 345                   (Ice cream, Eggs)                       (Corn, Onion)
# 349                         (Ice cream)                 (Corn, Onion, Eggs)
# 360         (Kidney Beans, Corn, Onion)                         (Ice cream)
# 366           (Kidney Beans, Ice cream)                       (Corn, Onion)
# 367                       (Corn, Onion)           (Kidney Beans, Ice cream)
# 373                         (Ice cream)         (Kidney Beans, Corn, Onion)
# 375          (Kidney Beans, Corn, Milk)                           (Unicorn)
# 379             (Kidney Beans, Unicorn)                        (Milk, Corn)
# 382                        (Milk, Corn)             (Kidney Beans, Unicorn)
# 386                           (Unicorn)          (Kidney Beans, Corn, Milk)
# 403        (Kidney Beans, Corn, Yogurt)                           (Unicorn)
# 407             (Kidney Beans, Unicorn)                      (Corn, Yogurt)
# 410                      (Corn, Yogurt)             (Kidney Beans, Unicorn)
# 414                           (Unicorn)        (Kidney Beans, Corn, Yogurt)
# 417                (Milk, Corn, Yogurt)                           (Unicorn)
# 420                        (Milk, Corn)                   (Unicorn, Yogurt)
# 421                     (Milk, Unicorn)                      (Corn, Yogurt)
# 424                      (Corn, Yogurt)                     (Milk, Unicorn)
# 425                   (Unicorn, Yogurt)                        (Milk, Corn)
# 428                           (Unicorn)                (Milk, Corn, Yogurt)
# 762   (Kidney Beans, Corn, Onion, Eggs)                         (Ice cream)
# 764     (Kidney Beans, Ice cream, Eggs)                       (Corn, Onion)
# 768    (Kidney Beans, Ice cream, Onion)                        (Corn, Eggs)
# 769          (Kidney Beans, Corn, Eggs)                  (Ice cream, Onion)
# 770                 (Corn, Onion, Eggs)           (Kidney Beans, Ice cream)
# 772         (Kidney Beans, Corn, Onion)                   (Ice cream, Eggs)
# 773                   (Ice cream, Eggs)         (Kidney Beans, Corn, Onion)
# 775           (Kidney Beans, Ice cream)                 (Corn, Onion, Eggs)
# 776                  (Ice cream, Onion)          (Kidney Beans, Corn, Eggs)
# 777                        (Corn, Eggs)    (Kidney Beans, Ice cream, Onion)
# 781                       (Corn, Onion)     (Kidney Beans, Ice cream, Eggs)
# 783                         (Ice cream)   (Kidney Beans, Corn, Onion, Eggs)
# 790  (Kidney Beans, Milk, Corn, Yogurt)                           (Unicorn)
# 794                (Milk, Corn, Yogurt)             (Kidney Beans, Unicorn)
# 795          (Kidney Beans, Milk, Corn)                   (Unicorn, Yogurt)
# 797       (Kidney Beans, Milk, Unicorn)                      (Corn, Yogurt)
# 801        (Kidney Beans, Corn, Yogurt)                     (Milk, Unicorn)
# 802     (Kidney Beans, Unicorn, Yogurt)                        (Milk, Corn)
# 803                        (Milk, Corn)     (Kidney Beans, Unicorn, Yogurt)
# 804                     (Milk, Unicorn)        (Kidney Beans, Corn, Yogurt)
# 808                      (Corn, Yogurt)       (Kidney Beans, Milk, Unicorn)
# 810                   (Unicorn, Yogurt)          (Kidney Beans, Milk, Corn)
# 811             (Kidney Beans, Unicorn)                (Milk, Corn, Yogurt)
# 815                           (Unicorn)  (Kidney Beans, Milk, Corn, Yogurt)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 75                  0.2                 0.2      0.2         1.0   5.0
# 78                  0.2                 0.2      0.2         1.0   5.0
# 92                  0.2                 0.2      0.2         1.0   5.0
# 97                  0.2                 0.2      0.2         1.0   5.0
# 110                 0.2                 0.2      0.2         1.0   5.0
# 115                 0.2                 0.2      0.2         1.0   5.0
# 123                 0.2                 0.2      0.2         1.0   5.0
# 126                 0.2                 0.2      0.2         1.0   5.0
# 323                 0.2                 0.2      0.2         1.0   5.0
# 327                 0.2                 0.2      0.2         1.0   5.0
# 330                 0.2                 0.2      0.2         1.0   5.0
# 334                 0.2                 0.2      0.2         1.0   5.0
# 336                 0.2                 0.2      0.2         1.0   5.0
# 340                 0.2                 0.2      0.2         1.0   5.0
# 341                 0.2                 0.2      0.2         1.0   5.0
# 344                 0.2                 0.2      0.2         1.0   5.0
# 345                 0.2                 0.2      0.2         1.0   5.0
# 349                 0.2                 0.2      0.2         1.0   5.0
# 360                 0.2                 0.2      0.2         1.0   5.0
# 366                 0.2                 0.2      0.2         1.0   5.0
# 367                 0.2                 0.2      0.2         1.0   5.0
# 373                 0.2                 0.2      0.2         1.0   5.0
# 375                 0.2                 0.2      0.2         1.0   5.0
# 379                 0.2                 0.2      0.2         1.0   5.0
# 382                 0.2                 0.2      0.2         1.0   5.0
# 386                 0.2                 0.2      0.2         1.0   5.0
# 403                 0.2                 0.2      0.2         1.0   5.0
# 407                 0.2                 0.2      0.2         1.0   5.0
# 410                 0.2                 0.2      0.2         1.0   5.0
# 414                 0.2                 0.2      0.2         1.0   5.0
# 417                 0.2                 0.2      0.2         1.0   5.0
# 420                 0.2                 0.2      0.2         1.0   5.0
# 421                 0.2                 0.2      0.2         1.0   5.0
# 424                 0.2                 0.2      0.2         1.0   5.0
# 425                 0.2                 0.2      0.2         1.0   5.0
# 428                 0.2                 0.2      0.2         1.0   5.0
# 762                 0.2                 0.2      0.2         1.0   5.0
# 764                 0.2                 0.2      0.2         1.0   5.0
# 768                 0.2                 0.2      0.2         1.0   5.0
# 769                 0.2                 0.2      0.2         1.0   5.0
# 770                 0.2                 0.2      0.2         1.0   5.0
# 772                 0.2                 0.2      0.2         1.0   5.0
# 773                 0.2                 0.2      0.2         1.0   5.0
# 775                 0.2                 0.2      0.2         1.0   5.0
# 776                 0.2                 0.2      0.2         1.0   5.0
# 777                 0.2                 0.2      0.2         1.0   5.0
# 781                 0.2                 0.2      0.2         1.0   5.0
# 783                 0.2                 0.2      0.2         1.0   5.0
# 790                 0.2                 0.2      0.2         1.0   5.0
# 794                 0.2                 0.2      0.2         1.0   5.0
# 795                 0.2                 0.2      0.2         1.0   5.0
# 797                 0.2                 0.2      0.2         1.0   5.0
# 801                 0.2                 0.2      0.2         1.0   5.0
# 802                 0.2                 0.2      0.2         1.0   5.0
# 803                 0.2                 0.2      0.2         1.0   5.0
# 804                 0.2                 0.2      0.2         1.0   5.0
# 808                 0.2                 0.2      0.2         1.0   5.0
# 810                 0.2                 0.2      0.2         1.0   5.0
# 811                 0.2                 0.2      0.2         1.0   5.0
# 815                 0.2                 0.2      0.2         1.0   5.0
#
#      leverage  conviction
# 75       0.16         inf
# 78       0.16         inf
# 92       0.16         inf
# 97       0.16         inf
# 110      0.16         inf
# 115      0.16         inf
# 123      0.16         inf
# 126      0.16         inf
# 323      0.16         inf
# 327      0.16         inf
# 330      0.16         inf
# 334      0.16         inf
# 336      0.16         inf
# 340      0.16         inf
# 341      0.16         inf
# 344      0.16         inf
# 345      0.16         inf
# 349      0.16         inf
# 360      0.16         inf
# 366      0.16         inf
# 367      0.16         inf
# 373      0.16         inf
# 375      0.16         inf
# 379      0.16         inf
# 382      0.16         inf
# 386      0.16         inf
# 403      0.16         inf
# 407      0.16         inf
# 410      0.16         inf
# 414      0.16         inf
# 417      0.16         inf
# 420      0.16         inf
# 421      0.16         inf
# 424      0.16         inf
# 425      0.16         inf
# 428      0.16         inf
# 762      0.16         inf
# 764      0.16         inf
# 768      0.16         inf
# 769      0.16         inf
# 770      0.16         inf
# 772      0.16         inf
# 773      0.16         inf
# 775      0.16         inf
# 776      0.16         inf
# 777      0.16         inf
# 781      0.16         inf
# 783      0.16         inf
# 790      0.16         inf
# 794      0.16         inf
# 795      0.16         inf
# 797      0.16         inf
# 801      0.16         inf
# 802      0.16         inf
# 803      0.16         inf
# 804      0.16         inf
# 808      0.16         inf
# 810      0.16         inf
# 811      0.16         inf
# 815      0.16         inf
